# %%
import PIL

# %%
from PIL import Image

image = Image.open('My_GA_one.png')
image.load()

# %%
print ('Начальные условия: [0.0, -2, 1], \n Количество итераций - 1000, \n Сила мутации - 0.7 \n Вероятность мутации - 0.6')
image
# Out:
# Начальные условия: [0.0, -2, 1],
#  Количество итераций - 1000,
#  Сила мутации - 0.7
#  Вероятность мутации - 0.6
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x288 at 0x7F859DB368D0>

# %%
image = Image.open('My_GA_one_2.png')
image.load()
print ('Начальные условия: [0.0, -2, 1], \n Количество итераций - 100, \n Сила мутации - 0.7 \n Вероятность мутации - 0.6')
image
# Out:
# Начальные условия: [0.0, -2, 1],
#  Количество итераций - 100,
#  Сила мутации - 0.7
#  Вероятность мутации - 0.6
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x288 at 0x7F859DB4C090>

# %%
image = Image.open('My_GA_one_3.png')
image.load()
print ('Начальные условия: [0.0, -2, 1], \n Количество итераций - 1000, \n Сила мутации - 0.7 \n Вероятность мутации - 1.')
image
# Out:
# Начальные условия: [0.0, -2, 1],
#  Количество итераций - 1000,
#  Сила мутации - 0.7
#  Вероятность мутации - 1.
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x288 at 0x7F85AFC22E50>

# %%
image = Image.open('Lib_GA_one.png')
image.load()
print ('Начальные условия: [0.0, -2, 1], GA-алгоритм из библиотеки, \n Размер популяции - 100 \n Вероятность мутации - 0.6')
image
# Out:
# Начальные условия: [0.0, -2, 1], GA-алгоритм из библиотеки,
#  Размер популяции - 100
#  Вероятность мутации - 0.6
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x288 at 0x7F859DB36CD0>

# %%
image = Image.open('Twidle_one.png')
image.load()
print ('Начальные условия: [0.0, -2, 1], Twidle алгоритм')
image
# Out:
# Начальные условия: [0.0, -2, 1], Twidle алгоритм
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x288 at 0x7F859DB36B50>
